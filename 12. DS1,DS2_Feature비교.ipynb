# %%
import pandas as pd

# %% [markdown]
# # KOSPI+KOSDAQ

# %%
train_df = pd.read_csv('./datasets/KOSDAQ+KOSPI_TRAIN_DATA.csv', index_col=0)
train_df = train_df.iloc[:,2:]
test_df = pd.read_csv('./datasets/KOSDAQ+KOSPI_TEST1_DATA.csv', index_col=0)
test_df = test_df.iloc[:,2:]

# %%
train_df = train_df[['총자본증가율',
 '총자본순이익률',
 '자기자본순이익률',
 '매출원가대매출액비율',
 '금융비용대총비용비율',
 '자기자본구성비율',
 '순운전자본비율',
 'CASHFLOW대총자본비율',
 '순운전자본회전률', 'label', '1주당순이익', '1주당정상영업이익']]

# %%
round(train_df[train_df['label'] == 1].describe().T,4)
# Out:
#                 count       mean        std        min        25%       50%  \
# 총자본증가율          129.0   -19.4755    38.6680    -94.942   -43.4267  -23.6505
# 총자본순이익률         129.0   -33.0753    24.5386    -70.590   -50.1600  -31.0400
# 자기자본순이익률        129.0   -77.8747    73.1032   -196.400  -144.5800  -60.1500
# 매출원가대매출액비율      129.0    91.4215    22.4967     16.810    81.4400   95.4000
# 금융비용대총비용비율      129.0     3.4506     3.6928     -7.310     0.9100    2.9300
# 자기자본구성비율        129.0    29.5260    28.0174      0.000     2.9500   22.8000
# 순운전자본비율         129.0   -13.9915    32.9788    -58.560   -41.2800  -15.3100
# CASHFLOW대총자본비율  129.0    -7.8666    12.9849    -31.040   -14.8400   -5.3800
# 순운전자본회전률        129.0     0.5829     0.4259      0.010     0.3200    0.5100
# label           129.0     1.0000     0.0000      1.000     1.0000    1.0000
# 1주당순이익          129.0 -1819.4426  4460.2623 -32296.000 -1637.0000 -622.0000
# ...

# %%
round(train_df[train_df['label'] == 0].describe().T,4)
# Out:
#                   count       mean        std         min     25%       50%  \
# 총자본증가율          11389.0     9.2662    28.8289    -95.8445  -2.811    4.4914
# 총자본순이익률         11389.0     0.8916    11.1834    -70.5900  -1.350    2.5500
# 자기자본순이익률        11389.0    -1.1596    28.1032   -196.4000  -2.690    4.8000
# 매출원가대매출액비율      11389.0    75.5347    22.2703      0.0000  68.760   81.9100
# 금융비용대총비용비율      11389.0     0.7777     2.2308     -7.5600  -0.230    0.4800
# 자기자본구성비율        11389.0    56.2130    20.9111      0.0000  40.670   56.0700
# 순운전자본비율         11389.0    17.3885    24.9252    -58.5600   0.190   16.5700
# CASHFLOW대총자본비율  11389.0     4.1553     7.6208    -31.0400   0.330    4.5000
# 순운전자본회전률        11389.0     1.1468     0.5507      0.0100   0.770    1.0800
# label           11389.0     0.0000     0.0000      0.0000   0.000    0.0000
# 1주당순이익          11389.0  1318.2714  6232.7666 -32296.0000 -69.000  221.0000
# ...

# %%
test_df = test_df[['총자본증가율',
 '총자본순이익률',
 '자기자본순이익률',
 '매출원가대매출액비율',
 '금융비용대총비용비율',
 '자기자본구성비율',
 '순운전자본비율',
 'CASHFLOW대총자본비율',
 '순운전자본회전률', 'label', '1주당순이익', '1주당정상영업이익']]

# %% [markdown]
# # KOSDAQ

# %%
train_df = pd.read_csv('./datasets/KOSDAQ_TRAIN_DATA.csv', index_col=0)
train_df = train_df.iloc[:,2:]
test_df = pd.read_csv('./datasets/KOSDAQ_TEST1_DATA.csv', index_col=0)
test_df = test_df.iloc[:,2:]

# %%
train_df = train_df[['총자본증가율',
 '총자본순이익률',
 '자기자본순이익률',
 '매출원가대매출액비율',
 '금융비용대총비용비율',
 '자기자본구성비율',
 '순운전자본비율',
 'CASHFLOW대총자본비율',
 '순운전자본회전률', 'label', '1주당순이익', '1주당정상영업이익']]

# %%
round(train_df[train_df['label'] == 1].describe().T,4)
# Out:
#                 count      mean        std       min        25%       50%  \
# 총자본증가율          107.0  -21.2431    40.3604   -94.942   -45.1531  -26.2526
# 총자본순이익률         107.0  -35.1169    25.2103   -70.590   -61.2750  -31.7300
# 자기자본순이익률        107.0  -79.7471    71.3640  -187.110  -143.6150  -64.8000
# 매출원가대매출액비율      107.0   90.3286    23.3124    16.810    80.4100   94.4100
# 금융비용대총비용비율      107.0    3.1562     3.6050    -7.310     0.8550    2.4600
# 자기자본구성비율        107.0   31.8171    28.8667     0.000     4.6700   24.2500
# 순운전자본비율         107.0  -15.3286    34.2443   -58.560   -45.9400  -19.1400
# CASHFLOW대총자본비율  107.0   -8.7255    13.5085   -31.040   -15.5900   -7.5500
# 순운전자본회전률        107.0    0.5670     0.3922     0.010     0.3200    0.5100
# label           107.0    1.0000     0.0000     1.000     1.0000    1.0000
# 1주당순이익          107.0 -987.7019  1202.2230 -4521.000 -1266.0000 -607.0000
# 1주당정상영업이익       107.0 -626.7586   971.5852 -3819.450  -848.3450 -251.9200
#
# ...

# %%
round(train_df[train_df['label'] == 0].describe().T,4)
# Out:
#                  count      mean        std        min       25%       50%  \
# 총자본증가율          6866.0   11.5630    32.8417   -95.8445   -3.2623    5.4979
# 총자본순이익률         6866.0    0.2751    12.5866   -70.5900   -2.7800    2.4000
# 자기자본순이익률        6866.0   -2.0984    28.2433  -187.1100   -5.3600    4.3400
# 매출원가대매출액비율      6866.0   73.4930    23.6095     0.0000   65.5700   79.9800
# 금융비용대총비용비율      6866.0    0.6944     2.4060    -7.5600   -0.3600    0.4300
# 자기자본구성비율        6866.0   58.9988    20.6363     0.0000   43.2275   59.3750
# 순운전자본비율         6866.0   20.8896    26.2801   -58.5600    2.4200   21.1000
# CASHFLOW대총자본비율  6866.0    3.9700     8.4371   -31.0400   -0.3875    4.5200
# 순운전자본회전률        6866.0    1.0743     0.5331     0.0100    0.7100    1.0100
# label           6866.0    0.0000     0.0000     0.0000    0.0000    0.0000
# 1주당순이익          6866.0  362.1107  1483.9739 -4521.0000 -113.0000  139.0000
# ...
