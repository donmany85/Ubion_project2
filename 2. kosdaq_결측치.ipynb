# %%
import pandas as pd
import numpy as np
# pd.set_option('display.max_rows',None)

# %%
# 데이터로드
kosdaq = pd.read_csv('./datasets/1.kosdaq_preprocessing완료.csv', index_col=0)
kosdaq
# Out:
#             회사명  거래소코드     회계년도      총자본증가율    유형자산증가율     유동자산증가율   비유동자산증가율  \
# 0      (주)CMG제약  58820  2011/12    1.975650  -5.902879   17.636684 -12.887724
# 1      (주)CMG제약  58820  2012/12  109.148508  -4.130614  207.079069 -16.424273
# 2      (주)CMG제약  58820  2013/12   -2.092526  16.095412  -18.890233  77.047705
# 3      (주)CMG제약  58820  2014/12    3.854202  74.308191  -25.933002  68.146642
# 4      (주)CMG제약  58820  2015/12   -2.643453  -5.373261   -7.169358   1.659556
# ...         ...    ...      ...         ...        ...         ...        ...
# 12091   흥구석유(주)  24060  2017/12    0.979314  -0.565031    7.340814  -0.484894
# 12092   흥구석유(주)  24060  2018/12   -5.888978  -0.359446  -21.190176  -2.094265
# 12093   흥구석유(주)  24060  2019/12   11.242454  -7.005305   80.743108  -2.630362
# 12094   흥구석유(주)  24060  2020/12    0.071718 -13.916541   22.404951  -8.205825
# 12095   흥구석유(주)  24060  2021/12   -1.282832   0.629556   -4.236492   0.178466
#
#          재고자산증가율    자기자본증가율     매출액증가율  ...  순운전자본회전률  영업활동현금흐름  투자활동현금흐름  \
# 0      -1.437298  -2.015757  56.405286  ...      0.86   -2560.0   -1773.0
# 1       7.728764  75.174670  -8.432853  ...      0.42   -1573.0  -30266.0
# 2      56.311337  55.097971  25.512150  ...      0.42   -3939.0   21135.0
# 3       6.365014   0.012246  11.523380  ...      0.56     725.0  -13611.0
# 4      11.052310  -4.481358  18.850262  ...      0.75    2410.0   -8671.0
# ...          ...        ...        ...  ...       ...       ...       ...
# 12091   9.408495   0.832635   8.117296  ...      7.20    1558.0      58.0
# 12092 -46.081277   0.986323   6.874490  ...      8.08    5043.0    4839.0
# 12093  96.433378   9.311206  -9.349129  ...      6.91     731.0    -181.0
# 12094 -18.636519   3.375281 -23.777287  ...      4.00    1721.0      17.0
# 12095  16.168421  -0.884422  15.124865  ...      4.44    -587.0    2558.0
#
#        재무활동현금흐름  현금및현금성자산의증가     기업생애주기  통계청 한국표준산업분류 10차(대분류)  경영기간  상장기간  \
# 0        3039.0      -1295.0        도입기                    제조업  10.0  11.0
# 1       35361.0       3522.0        도입기                    제조업  11.0  12.0
# 2        -157.0      17031.0        쇠퇴기                    제조업  12.0  13.0
# 3           5.0     -12878.0        성장기                    제조업  13.0  14.0
# 4           1.0      -6261.0        성장기                    제조업  14.0  15.0
# ...         ...          ...        ...                    ...   ...   ...
# 12091   -1468.0        148.0  Shake-Out               도매 및 소매업  51.0  24.0
# 12092   -7453.0       2429.0  Shake-Out               도매 및 소매업  52.0  25.0
# 12093   -2249.0      -1699.0        성숙기               도매 및 소매업  53.0  26.0
# 12094   -2643.0       -905.0  Shake-Out               도매 및 소매업  54.0  27.0
# 12095   -2457.0       -486.0        쇠퇴기               도매 및 소매업  55.0  28.0
#
#        label
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 12091      0
# 12092      0
# 12093      0
# 12094      0
# 12095      0
#
# [12096 rows x 66 columns]

# %%
# 결과창 늘려주는 코드 시작
pd.set_option('display.max_rows',None)
# 결측치 확인
kosdaq.isna().sum()
# Out:
# 회사명                        0
# 거래소코드                      0
# 회계년도                       0
# 총자본증가율                   526
# 유형자산증가율                  525
# 유동자산증가율                  526
# 비유동자산증가율                 525
# 재고자산증가율                  503
# 자기자본증가율                  526
# 매출액증가율                   524
# 매출총이익증가율                 524
# 당기순이익증가율                 526
# 정상영업손익증가율                526
# 매출액총이익률                  363
# 매출액순이익률                  363
# 총자본순이익률                  363
# 자기자본순이익률                 363
# 매출원가대매출액비율               363
# 영업비용대영업수익비율              363
# 기업순이익률                   363
# 금융비용대총비용비율               363
# 이자부담률                    363
# 1주당매출액                   363
# 1주당순이익                   363
# 1주당CASHFLOW              363
# 1주당정상영업이익                363
# 유동자산구성비율                 369
# 재고자산대유동자산비율              369
# 유동자산대비유동자산비율             369
# 당좌자산구성비율                 369
# 비유동자산구성비율                369
# 자기자본구성비율                 369
# 타인자본구성비율                 369
# 비유동비율                    369
# 유동비율                     369
# 당좌비율                     369
# 현금비율                     369
# 매입채무대재고자산비율              369
# 부채비율                     369
# 유동부채비율                   369
# 단기차입금대총차입금비율             369
# 순운전자본비율                  369
# 차입금비율                    369
# CASHFLOW대부채비율            369
# CASHFLOW대차입금비율           369
# CASHFLOW대총자본비율           369
# CASHFLOW대매출액비율           369
# 총자본회전률                   363
# 자기자본회전률                  363
# 타인자본회전률                  363
# 매입채무회전률                  363
# 유동자산회전률                  363
# 당좌자산회전률                  363
# 재고자산회전률                  363
# 매출채권회전률                  363
# 유형자산회전율                  363
# 순운전자본회전률                 363
# 영업활동현금흐름                 340
# 투자활동현금흐름                 340
# 재무활동현금흐름                 340
# 현금및현금성자산의증가              340
# 기업생애주기                     0
# 통계청 한국표준산업분류 10차(대분류)      0
# 경영기간                       0
# 상장기간                       0
# label                      0
# dtype: int64

# %%
# 결과창 늘려주는 코드 종료
pd.reset_option('display.max_rows', None)

# %%
# 상장폐지기업 확인
kosdaq['label'].value_counts()
# Out:
# 0    11942
# 1      154
# Name: label, dtype: int64

# %%
# 성장성 결측치 확인 - 526개
kosdaq[kosdaq['총자본증가율'].isna()]
# Out:
#               회사명   거래소코드     회계년도  총자본증가율  유형자산증가율  유동자산증가율  비유동자산증가율  \
# 33     (주)강스템바이오텍  217730  2015/12     NaN      NaN      NaN       NaN
# 40       (주)강원에너지  114190  2012/12     NaN      NaN      NaN       NaN
# 50       (주)고려시멘트  198440  2014/12     NaN      NaN      NaN       NaN
# 51       (주)고려시멘트  198440  2015/12     NaN      NaN      NaN       NaN
# 52       (주)고려시멘트  198440  2016/12     NaN      NaN      NaN       NaN
# ...           ...     ...      ...     ...      ...      ...       ...
# 12036     화성밸브(주)   39610  2018/12     NaN      NaN      NaN       NaN
# 12070     휴마시스(주)  205470  2014/12     NaN      NaN      NaN       NaN
# 12071     휴마시스(주)  205470  2015/12     NaN      NaN      NaN       NaN
# 12072     휴마시스(주)  205470  2016/12     NaN      NaN      NaN       NaN
# 12073     휴마시스(주)  205470  2017/12     NaN      NaN      NaN       NaN
#
#        재고자산증가율  자기자본증가율  매출액증가율  ...  순운전자본회전률  영업활동현금흐름  투자활동현금흐름  재무활동현금흐름  \
# 33         NaN      NaN     NaN  ...      0.07   -3800.0  -12059.0   21490.0
# 40         NaN      NaN     NaN  ...      0.80   -3145.0  -21039.0   12887.0
# 50         NaN      NaN     NaN  ...       NaN       NaN       NaN       NaN
# 51         NaN      NaN     NaN  ...       NaN       NaN       NaN       NaN
# 52         NaN      NaN     NaN  ...       NaN       NaN       NaN       NaN
# ...        ...      ...     ...  ...       ...       ...       ...       ...
# 12036      NaN      NaN     NaN  ...      0.93     193.0   -2181.0    4360.0
# 12070      NaN      NaN     NaN  ...       NaN       NaN       NaN       NaN
# 12071      NaN      NaN     NaN  ...       NaN       NaN       NaN       NaN
# 12072      NaN      NaN     NaN  ...       NaN       NaN       NaN       NaN
# 12073      NaN      NaN     NaN  ...      0.33   -2389.0  -10385.0   13723.0
#
#        현금및현금성자산의증가     기업생애주기  통계청 한국표준산업분류 10차(대분류)  경영기간  상장기간  label
# 33          5631.0        도입기                    제조업   5.0   1.0      0
# 40        -11319.0        도입기                    제조업  36.0   4.0      0
# 50             NaN  Shake-Out                    제조업   0.0   1.0      0
# 51             NaN  Shake-Out                    제조업   1.0   2.0      0
# 52             NaN  Shake-Out                    제조업   2.0   3.0      0
# ...            ...        ...                    ...   ...   ...    ...
# 12036       2376.0        성장기                    제조업  31.0  19.0      0
# 12070          NaN  Shake-Out                    제조업   0.0   1.0      0
# 12071          NaN  Shake-Out                    제조업   1.0   2.0      0
# 12072          NaN  Shake-Out                    제조업   2.0   3.0      0
# 12073        910.0        도입기                    제조업   3.0   4.0      0
#
# [526 rows x 66 columns]

# %%
kosdaq[kosdaq['총자본증가율'].isna()]['label'].value_counts()
# Out:
# 0    526
# Name: label, dtype: int64

# %%
# 성장성 결측치 제거 - 528개 제거
kosdaq_na = kosdaq[~kosdaq['총자본증가율'].isna()]
kosdaq_na.shape
# Out:
# (11570, 66)

# %%
# 수익성 결측치 확인 - 1개
kosdaq_na[kosdaq_na['매출액총이익률'].isna()].iloc[:,13:]
# Out:
#       매출액총이익률  매출액순이익률  총자본순이익률  자기자본순이익률  매출원가대매출액비율  영업비용대영업수익비율  기업순이익률  \
# 4402      NaN      NaN      NaN       NaN         NaN          NaN     NaN
#
#       금융비용대총비용비율  이자부담률  1주당매출액  ...  순운전자본회전률  영업활동현금흐름  투자활동현금흐름  재무활동현금흐름  \
# 4402         NaN    NaN     NaN  ...       0.1   -3832.0   -6191.0    9993.0
#
#       현금및현금성자산의증가  기업생애주기  통계청 한국표준산업분류 10차(대분류)  경영기간  상장기간  label
# 4402        -51.0     도입기                    제조업  15.0   3.0      0
#
# [1 rows x 53 columns]

# %%
# 수익성 결측치 제거 - 1개 제거
kosdaq_na = kosdaq_na[~kosdaq_na['매출액총이익률'].isna()]
kosdaq_na.shape
# Out:
# (11569, 66)

# %%
# 안정성 결측치 확인 - 1개
kosdaq_na[kosdaq_na['유동자산구성비율'].isna()].iloc[:,28:]
# Out:
#        유동자산대비유동자산비율  당좌자산구성비율  비유동자산구성비율  자기자본구성비율  타인자본구성비율  비유동비율  유동비율  \
# 10863           NaN       NaN        NaN       NaN       NaN    NaN   NaN
#
#        당좌비율  현금비율  매입채무대재고자산비율  ...  순운전자본회전률  영업활동현금흐름  투자활동현금흐름  재무활동현금흐름  \
# 10863   NaN   NaN          NaN  ...       NaN    1156.0     964.0    -363.0
#
#        현금및현금성자산의증가     기업생애주기  통계청 한국표준산업분류 10차(대분류)  경영기간  상장기간  label
# 10863       1757.0  Shake-Out                    제조업  21.0   6.0      0
#
# [1 rows x 38 columns]

# %%
# 안정성 결측치 제거 - 1개 제거
kosdaq_na = kosdaq_na[~kosdaq_na['유동자산구성비율'].isna()]
kosdaq_na.shape
# Out:
# (11568, 66)

# %%
# 활동성 결측치 확인 - 1개
kosdaq_na[kosdaq_na['총자본회전률'].isna()].iloc[:,49:]
# Out:
#        타인자본회전률  매입채무회전률  유동자산회전률  당좌자산회전률  재고자산회전률  매출채권회전률  유형자산회전율  \
# 10864      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        순운전자본회전률  영업활동현금흐름  투자활동현금흐름  재무활동현금흐름  현금및현금성자산의증가 기업생애주기  \
# 10864       NaN    6091.0   -5722.0    -796.0       -387.0    성숙기
#
#       통계청 한국표준산업분류 10차(대분류)  경영기간  상장기간  label
# 10864                   제조업   2.0   3.0      0

# %%
# 활동성 결측치 제거 - 1개 제거
kosdaq_na = kosdaq_na[~kosdaq_na['총자본회전률'].isna()]
kosdaq_na.shape
# Out:
# (11567, 66)

# %%
# 결과창 늘려주는 코드 시작
pd.set_option('display.max_rows',None)
# 결측치 확인
kosdaq_na.isna().sum()
# Out:
# 회사명                      0
# 거래소코드                    0
# 회계년도                     0
# 총자본증가율                   0
# 유형자산증가율                  0
# 유동자산증가율                  0
# 비유동자산증가율                 0
# 재고자산증가율                  0
# 자기자본증가율                  0
# 매출액증가율                   0
# 매출총이익증가율                 0
# 당기순이익증가율                 0
# 정상영업손익증가율                0
# 매출액총이익률                  0
# 매출액순이익률                  0
# 총자본순이익률                  0
# 자기자본순이익률                 0
# 매출원가대매출액비율               0
# 영업비용대영업수익비율              0
# 기업순이익률                   0
# 금융비용대총비용비율               0
# 이자부담률                    0
# 1주당매출액                   0
# 1주당순이익                   0
# 1주당CASHFLOW              0
# 1주당정상영업이익                0
# 유동자산구성비율                 0
# 재고자산대유동자산비율              0
# 유동자산대비유동자산비율             0
# 당좌자산구성비율                 0
# 비유동자산구성비율                0
# 자기자본구성비율                 0
# 타인자본구성비율                 0
# 비유동비율                    0
# 유동비율                     0
# 당좌비율                     0
# 현금비율                     0
# 매입채무대재고자산비율              0
# 부채비율                     0
# 유동부채비율                   0
# 단기차입금대총차입금비율             0
# 순운전자본비율                  0
# 차입금비율                    0
# CASHFLOW대부채비율            0
# CASHFLOW대차입금비율           0
# CASHFLOW대총자본비율           0
# CASHFLOW대매출액비율           0
# 총자본회전률                   0
# 자기자본회전률                  0
# 타인자본회전률                  0
# 매입채무회전률                  0
# 유동자산회전률                  0
# 당좌자산회전률                  0
# 재고자산회전률                  0
# 매출채권회전률                  0
# 유형자산회전율                  0
# 순운전자본회전률                 0
# 영업활동현금흐름                 0
# 투자활동현금흐름                 0
# 재무활동현금흐름                 0
# 현금및현금성자산의증가              0
# 기업생애주기                   0
# 통계청 한국표준산업분류 10차(대분류)    0
# 경영기간                     0
# 상장기간                     0
# label                    0
# dtype: int64

# %%
# 결과창 늘려주는 코드 종료
pd.reset_option('display.max_rows', None)

# %%
# 결측치 제거 후 인덱스 초기화
kosdaq_na.reset_index(drop=True, inplace=True)

# %%
kosdaq_na.to_csv('./datasets/2.kosdaq_결측치제거완료.csv')
