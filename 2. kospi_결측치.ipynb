# %%
import pandas as pd
import numpy as np
# pd.set_option('display.max_rows',None)

# %%
# 데이터로드
kosdaq = pd.read_csv('./datasets/1.kospi_preprocessing완료.csv', index_col=0)
kosdaq
# Out:
#            회사명  거래소코드     회계년도     총자본증가율    유형자산증가율    유동자산증가율   비유동자산증가율  \
# 0     (주)DB하이텍    990  2011/12 -13.191447  -7.891077 -10.081970 -14.095356
# 1     (주)DB하이텍    990  2012/12  -3.443493  -9.686758  10.516720  -7.691245
# 2     (주)DB하이텍    990  2013/12  -8.582386  -7.200145 -27.877947  -1.553126
# 3     (주)DB하이텍    990  2014/12  -6.945914  -6.957581  11.042738 -11.746871
# 4     (주)DB하이텍    990  2015/12  -0.023658  -9.910153  36.422276 -12.262137
# ...        ...    ...      ...        ...        ...        ...        ...
# 7384   흥아해운(주)   3280  2017/12 -11.431335 -16.501054  13.291350 -14.378792
# 7385   흥아해운(주)   3280  2018/12  -5.331353 -12.065399  -6.328074  -5.174121
# 7386   흥아해운(주)   3280  2019/12 -46.377495 -51.510121 -13.423469 -51.512707
# 7387   흥아해운(주)   3280  2020/12 -33.456932 -24.762048 -37.005650 -32.469532
# 7388   흥아해운(주)   3280  2021/12 -13.765796 -20.906906  -6.482782 -15.656115
#
# ...

# %%
# 결과창 늘려주는 코드 시작
pd.set_option('display.max_rows',None)
# 결측치 확인
kosdaq.isna().sum()
# Out:
# 회사명                       0
# 거래소코드                     0
# 회계년도                      0
# 총자본증가율                   63
# 유형자산증가율                  63
# 유동자산증가율                  63
# 비유동자산증가율                 63
# 재고자산증가율                  63
# 자기자본증가율                  63
# 매출액증가율                   63
# 매출총이익증가율                 63
# 당기순이익증가율                 63
# 정상영업손익증가율                63
# 매출액총이익률                  48
# 매출액순이익률                  48
# 총자본순이익률                  48
# 자기자본순이익률                 48
# 매출원가대매출액비율               48
# 영업비용대영업수익비율              48
# 기업순이익률                   48
# 금융비용대총비용비율               48
# 이자부담률                    48
# 1주당매출액                   48
# 1주당순이익                   48
# 1주당CASHFLOW              48
# 1주당정상영업이익                48
# 유동자산구성비율                 48
# 재고자산대유동자산비율              48
# 유동자산대비유동자산비율             48
# 당좌자산구성비율                 48
# 비유동자산구성비율                48
# 자기자본구성비율                 48
# 타인자본구성비율                 48
# ...

# %%
# 결과창 늘려주는 코드 종료
pd.reset_option('display.max_rows', None)

# %%
# 상장폐지기업 확인
kosdaq['label'].value_counts()
# Out:
# 0    7363
# 1      26
# Name: label, dtype: int64

# %%
# 성장성 결측치 확인 - 63개
kosdaq[kosdaq['총자본증가율'].isna()]
# Out:
#                 회사명   거래소코드     회계년도  총자본증가율  유형자산증가율  유동자산증가율  비유동자산증가율  \
# 143       (주)경동도시가스  267290  2017/12     NaN      NaN      NaN       NaN
# 391        (주)대구백화점    6370  2018/12     NaN      NaN      NaN       NaN
# 445           (주)대웅    3090  2011/12     NaN      NaN      NaN       NaN
# 456         (주)대웅제약   69620  2011/12     NaN      NaN      NaN       NaN
# 945      (주)비지에프리테일  282330  2017/12     NaN      NaN      NaN       NaN
# ...             ...     ...      ...     ...      ...      ...       ...
# 7290  현대코퍼레이션홀딩스(주)  227840  2015/12     NaN      NaN      NaN       NaN
# 7362       효성중공업(주)  298040  2018/12     NaN      NaN      NaN       NaN
# 7366      효성첨단소재(주)  298050  2018/12     NaN      NaN      NaN       NaN
# 7370       효성티앤씨(주)  298020  2018/12     NaN      NaN      NaN       NaN
# 7374        효성화학(주)  298000  2018/12     NaN      NaN      NaN       NaN
#
#       재고자산증가율  자기자본증가율  매출액증가율  ...  순운전자본회전률  영업활동현금흐름  투자활동현금흐름  재무활동현금흐름  \
# ...

# %%
kosdaq[kosdaq['총자본증가율'].isna()]['label'].value_counts()
# Out:
# 0    63
# Name: label, dtype: int64

# %%
# 성장성 결측치 제거 - 63개 제거
kosdaq_na = kosdaq[~kosdaq['총자본증가율'].isna()]
kosdaq_na.shape
# Out:
# (7326, 66)

# %%
# 수익성 결측치 확인 - 0개
kosdaq_na[kosdaq_na['매출액총이익률'].isna()].iloc[:,13:]
# Out:
# Empty DataFrame
# Columns: [매출액총이익률, 매출액순이익률, 총자본순이익률, 자기자본순이익률, 매출원가대매출액비율, 영업비용대영업수익비율, 기업순이익률, 금융비용대총비용비율, 이자부담률, 1주당매출액, 1주당순이익, 1주당CASHFLOW, 1주당정상영업이익, 유동자산구성비율, 재고자산대유동자산비율, 유동자산대비유동자산비율, 당좌자산구성비율, 비유동자산구성비율, 자기자본구성비율, 타인자본구성비율, 비유동비율, 유동비율, 당좌비율, 현금비율, 매입채무대재고자산비율, 부채비율, 유동부채비율, 단기차입금대총차입금비율, 순운전자본비율, 차입금비율, CASHFLOW대부채비율, CASHFLOW대차입금비율, CASHFLOW대총자본비율, CASHFLOW대매출액비율, 총자본회전률, 자기자본회전률, 타인자본회전률, 매입채무회전률, 유동자산회전률, 당좌자산회전률, 재고자산회전률, 매출채권회전률, 유형자산회전율, 순운전자본회전률, 영업활동현금흐름, 투자활동현금흐름, 재무활동현금흐름, 현금및현금성자산의증가, 기업생애주기, 통계청 한국표준산업분류 10차(대분류), 경영기간, 상장기간, label]
# Index: []
#
# [0 rows x 53 columns]

# %%
# 안정성 결측치 확인 - 0개
kosdaq_na[kosdaq_na['유동자산구성비율'].isna()].iloc[:,28:]
# Out:
# Empty DataFrame
# Columns: [유동자산대비유동자산비율, 당좌자산구성비율, 비유동자산구성비율, 자기자본구성비율, 타인자본구성비율, 비유동비율, 유동비율, 당좌비율, 현금비율, 매입채무대재고자산비율, 부채비율, 유동부채비율, 단기차입금대총차입금비율, 순운전자본비율, 차입금비율, CASHFLOW대부채비율, CASHFLOW대차입금비율, CASHFLOW대총자본비율, CASHFLOW대매출액비율, 총자본회전률, 자기자본회전률, 타인자본회전률, 매입채무회전률, 유동자산회전률, 당좌자산회전률, 재고자산회전률, 매출채권회전률, 유형자산회전율, 순운전자본회전률, 영업활동현금흐름, 투자활동현금흐름, 재무활동현금흐름, 현금및현금성자산의증가, 기업생애주기, 통계청 한국표준산업분류 10차(대분류), 경영기간, 상장기간, label]
# Index: []
#
# [0 rows x 38 columns]

# %%
# 활동성 결측치 확인 - 0개
kosdaq_na[kosdaq_na['총자본회전률'].isna()].iloc[:,49:]
# Out:
# Empty DataFrame
# Columns: [타인자본회전률, 매입채무회전률, 유동자산회전률, 당좌자산회전률, 재고자산회전률, 매출채권회전률, 유형자산회전율, 순운전자본회전률, 영업활동현금흐름, 투자활동현금흐름, 재무활동현금흐름, 현금및현금성자산의증가, 기업생애주기, 통계청 한국표준산업분류 10차(대분류), 경영기간, 상장기간, label]
# Index: []

# %%
# 결과창 늘려주는 코드 시작
pd.set_option('display.max_rows',None)
# 결측치 확인
kosdaq_na.isna().sum()
# Out:
# 회사명                      0
# 거래소코드                    0
# 회계년도                     0
# 총자본증가율                   0
# 유형자산증가율                  0
# 유동자산증가율                  0
# 비유동자산증가율                 0
# 재고자산증가율                  0
# 자기자본증가율                  0
# 매출액증가율                   0
# 매출총이익증가율                 0
# 당기순이익증가율                 0
# 정상영업손익증가율                0
# 매출액총이익률                  0
# 매출액순이익률                  0
# 총자본순이익률                  0
# 자기자본순이익률                 0
# 매출원가대매출액비율               0
# 영업비용대영업수익비율              0
# 기업순이익률                   0
# 금융비용대총비용비율               0
# 이자부담률                    0
# 1주당매출액                   0
# 1주당순이익                   0
# 1주당CASHFLOW              0
# 1주당정상영업이익                0
# 유동자산구성비율                 0
# 재고자산대유동자산비율              0
# 유동자산대비유동자산비율             0
# 당좌자산구성비율                 0
# 비유동자산구성비율                0
# 자기자본구성비율                 0
# 타인자본구성비율                 0
# 비유동비율                    0
# ...

# %%
# 결과창 늘려주는 코드 종료
pd.reset_option('display.max_rows', None)

# %%
# 결측치 제거 후 인덱스 초기화
kosdaq_na.reset_index(drop=True, inplace=True)

# %%
kosdaq_na.to_csv('./datasets/2.kospi_결측치제거완료.csv')
